# %%
# run the script if available
if os.path.exists("../backend/generate_report.py"):
    print("Running report script...")
    # !python ../backend/generate_report.py
elif os.path.exists("backend/generate_report.py"):
    # !python backend/generate_report.py
else:
    print("Script generate_report.py not found.")
